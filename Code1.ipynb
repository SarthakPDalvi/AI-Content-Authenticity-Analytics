# %%
import os
import re
import pandas as pd

import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')


STOPWORDS = set(stopwords.words('english'))

def load_texts(folder, label):
    data = []
    for file in os.listdir(folder):
        with open(os.path.join(folder, file), 'r', encoding='utf-8') as f:
            text = f.read()
            data.append({'text': text, 'label': label})
    return data

human = load_texts(
    r"E:\AI-Generated Content Detection Analytics\human_text",
    "Human"
)

ai = load_texts(
    r"E:\AI-Generated Content Detection Analytics\ai_text",
    "AI"
)


df = pd.DataFrame(human + ai)

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    words = word_tokenize(text)
    words = [w for w in words if w not in STOPWORDS]
    return words

df['tokens'] = df['text'].apply(clean_text)
df['sentences'] = df['text'].apply(sent_tokenize)

df.head()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                 text  label  \
# 0  I started learning data analysis during my fin...  Human
# 1  While working on my first internship, I realiz...  Human
# 2  Data analysis is an essential skill in today’s...     AI
# 3  Data analysis plays a crucial role in modern o...     AI
#
#                                               tokens  \
# 0  [started, learning, data, analysis, final, yea...
# 1  [working, first, internship, realized, dashboa...
# 2  [data, analysis, essential, skill, todays, dat...
# 3  [data, analysis, plays, crucial, role, modern,...
#
#                                            sentences
# 0  [I started learning data analysis during my fi...
# 1  [While working on my first internship, I reali...
# 2  [Data analysis is an essential skill in today’...
# 3  [Data analysis plays a crucial role in modern ...
